# %% [markdown]
# # 🧮 Sorting & Filtering in Pandas
#
# ## 🔹 LEARNING GOALS:
# - Sort rows using `.sort_values()`
# - Filter data using conditional logic
# - Chain multiple filters together
# - Use `.query()` for readable filtering

# %% [markdown]
# ### 📥 1. Load the Dataset

# %%
import pandas as pd

df = pd.read_csv("students.csv")
df.head()
# Out:
#   first_name last_name  math_score  science_score
# 0   Danielle      Wood         100             95
# 1      Angel     Clark          67             78
# 2     Joshua     Adams          61            100
# 3    Jeffrey    Zuniga          77             99
# 4       Jill      Wong          75             83

# %% [markdown]
# ### 🔢 2. Sorting Data

# %%
# Sort by math_score
df.sort_values(by="math_score")
# Out:
#      first_name  last_name  math_score  science_score
# 28      Melanie      Baker          60             94
# 2        Joshua      Adams          61            100
# 19         Adam      Adams          61             70
# 13        James      Cohen          61             66
# 12      Anthony    Hawkins          62             74
# 44  Christopher      Brown          62             64
# 14        Debra    Cameron          65             84
# 9       Anthony       Gray          65             74
# 37    Christine      Hicks          65             80
# 49      Michael   Valencia          65             91
# 39      Barbara   Williams          66             74
# 36        Maria     Bright          66             74
# 7   Christopher     Daniel          66             64
# 1         Angel      Clark          67             78
# 47       Joshua       Rice          67             80
# 6      Patricia    Jackson          68             72
# 33       Teresa      Hurst          69             77
# 29    Cassandra     Wright          70             75
# 21        Helen       Hahn          72             82
# 34     Nicholas       Ross          73            100
# 15          Amy    Parsons          73             77
# 5         Erica      Lynch          74             96
# 24        Susan       Rios          74             64
# 16      Jeffrey      Perez          74             89
# 4          Jill       Wong          75             83
# 43        Keith  Henderson          76             77
# 27        Colin      Ellis          77             70
# 3       Jeffrey     Zuniga          77             99
# 32       Amanda   Richards          77             84
# 35       Andrea   Robinson          81             95
# 31      Jessica      Baker          81             89
# 41      Brandon     Burton          82             80
# 40        Janet  Rodriguez          82             62
# 38     Michelle      Davis          84             63
# 48      Cynthia     Maddox          84             73
# 23         Eric    Edwards          86             77
# 30      Lindsay    Hoffman          87             70
# 11      William     Bowman          87             65
# 25      Matthew     Foster          88             98
# 45        Jesse      James          89             73
# 17      Bridget    Johnson          92            100
# 46        Craig    Ferrell          94             96
# 22      Matthew     Walter          94             73
# 8        Robert     Martin          94             62
# 20        Linda      Clark          95             83
# 26  Christopher      Rocha          97            100
# 10      Jeffery       Mayo          97             78
# 18         Lisa    Stewart          98             83
# 42       Jeremy     Conner          98             85
# 0      Danielle       Wood         100             95

# %%
# Sort by science_score descending
df.sort_values(by="science_score", ascending=False)
# Out:
#      first_name  last_name  math_score  science_score
# 17      Bridget    Johnson          92            100
# 2        Joshua      Adams          61            100
# 34     Nicholas       Ross          73            100
# 26  Christopher      Rocha          97            100
# 3       Jeffrey     Zuniga          77             99
# 25      Matthew     Foster          88             98
# 46        Craig    Ferrell          94             96
# 5         Erica      Lynch          74             96
# 0      Danielle       Wood         100             95
# 35       Andrea   Robinson          81             95
# 28      Melanie      Baker          60             94
# 49      Michael   Valencia          65             91
# 31      Jessica      Baker          81             89
# 16      Jeffrey      Perez          74             89
# 42       Jeremy     Conner          98             85
# 14        Debra    Cameron          65             84
# 32       Amanda   Richards          77             84
# 4          Jill       Wong          75             83
# 20        Linda      Clark          95             83
# 18         Lisa    Stewart          98             83
# 21        Helen       Hahn          72             82
# 41      Brandon     Burton          82             80
# 47       Joshua       Rice          67             80
# 37    Christine      Hicks          65             80
# 10      Jeffery       Mayo          97             78
# 1         Angel      Clark          67             78
# 43        Keith  Henderson          76             77
# 33       Teresa      Hurst          69             77
# 23         Eric    Edwards          86             77
# 15          Amy    Parsons          73             77
# 29    Cassandra     Wright          70             75
# 39      Barbara   Williams          66             74
# 12      Anthony    Hawkins          62             74
# 9       Anthony       Gray          65             74
# 36        Maria     Bright          66             74
# 48      Cynthia     Maddox          84             73
# 22      Matthew     Walter          94             73
# 45        Jesse      James          89             73
# 6      Patricia    Jackson          68             72
# 30      Lindsay    Hoffman          87             70
# 19         Adam      Adams          61             70
# 27        Colin      Ellis          77             70
# 13        James      Cohen          61             66
# 11      William     Bowman          87             65
# 24        Susan       Rios          74             64
# 7   Christopher     Daniel          66             64
# 44  Christopher      Brown          62             64
# 38     Michelle      Davis          84             63
# 8        Robert     Martin          94             62
# 40        Janet  Rodriguez          82             62

# %%
# Sort by multiple columns
df.sort_values(by=["science_score", "math_score"], ascending=[False, True])
# Out:
#      first_name  last_name  math_score  science_score
# 2        Joshua      Adams          61            100
# 34     Nicholas       Ross          73            100
# 17      Bridget    Johnson          92            100
# 26  Christopher      Rocha          97            100
# 3       Jeffrey     Zuniga          77             99
# 25      Matthew     Foster          88             98
# 5         Erica      Lynch          74             96
# 46        Craig    Ferrell          94             96
# 35       Andrea   Robinson          81             95
# 0      Danielle       Wood         100             95
# 28      Melanie      Baker          60             94
# 49      Michael   Valencia          65             91
# 16      Jeffrey      Perez          74             89
# 31      Jessica      Baker          81             89
# 42       Jeremy     Conner          98             85
# 14        Debra    Cameron          65             84
# 32       Amanda   Richards          77             84
# 4          Jill       Wong          75             83
# 20        Linda      Clark          95             83
# 18         Lisa    Stewart          98             83
# 21        Helen       Hahn          72             82
# 37    Christine      Hicks          65             80
# 47       Joshua       Rice          67             80
# 41      Brandon     Burton          82             80
# 1         Angel      Clark          67             78
# 10      Jeffery       Mayo          97             78
# 33       Teresa      Hurst          69             77
# 15          Amy    Parsons          73             77
# 43        Keith  Henderson          76             77
# 23         Eric    Edwards          86             77
# 29    Cassandra     Wright          70             75
# 12      Anthony    Hawkins          62             74
# 9       Anthony       Gray          65             74
# 36        Maria     Bright          66             74
# 39      Barbara   Williams          66             74
# 48      Cynthia     Maddox          84             73
# 45        Jesse      James          89             73
# 22      Matthew     Walter          94             73
# 6      Patricia    Jackson          68             72
# 19         Adam      Adams          61             70
# 27        Colin      Ellis          77             70
# 30      Lindsay    Hoffman          87             70
# 13        James      Cohen          61             66
# 11      William     Bowman          87             65
# 44  Christopher      Brown          62             64
# 7   Christopher     Daniel          66             64
# 24        Susan       Rios          74             64
# 38     Michelle      Davis          84             63
# 40        Janet  Rodriguez          82             62
# 8        Robert     Martin          94             62

# %% [markdown]
# ### 🧪 3. Filtering with Conditions

# %%
# Who scored at least 90 in math?
df[df["math_score"] >= 90]
# Out:
#      first_name last_name  math_score  science_score
# 0      Danielle      Wood         100             95
# 8        Robert    Martin          94             62
# 10      Jeffery      Mayo          97             78
# 17      Bridget   Johnson          92            100
# 18         Lisa   Stewart          98             83
# 20        Linda     Clark          95             83
# 22      Matthew    Walter          94             73
# 26  Christopher     Rocha          97            100
# 42       Jeremy    Conner          98             85
# 46        Craig   Ferrell          94             96

# %%
# Who scored less than 70 in either subject?
df[(df["math_score"] < 70) | (df["science_score"] < 70)]
# Out:
#      first_name  last_name  math_score  science_score
# 1         Angel      Clark          67             78
# 2        Joshua      Adams          61            100
# 6      Patricia    Jackson          68             72
# 7   Christopher     Daniel          66             64
# 8        Robert     Martin          94             62
# 9       Anthony       Gray          65             74
# 11      William     Bowman          87             65
# 12      Anthony    Hawkins          62             74
# 13        James      Cohen          61             66
# 14        Debra    Cameron          65             84
# 19         Adam      Adams          61             70
# 24        Susan       Rios          74             64
# 28      Melanie      Baker          60             94
# 33       Teresa      Hurst          69             77
# 36        Maria     Bright          66             74
# 37    Christine      Hicks          65             80
# 38     Michelle      Davis          84             63
# 39      Barbara   Williams          66             74
# 40        Janet  Rodriguez          82             62
# 44  Christopher      Brown          62             64
# 47       Joshua       Rice          67             80
# 49      Michael   Valencia          65             91

# %% [markdown]
# ### 🔗 4. Combining Filters

# %%
# Students with B+ or higher in both
df[(df["math_score"] >= 87) & (df["science_score"] >= 87)]
# Out:
#      first_name last_name  math_score  science_score
# 0      Danielle      Wood         100             95
# 17      Bridget   Johnson          92            100
# 25      Matthew    Foster          88             98
# 26  Christopher     Rocha          97            100
# 46        Craig   Ferrell          94             96

# %% [markdown]
# ### 🧾 5. Using `.query()` for Readability

# %%
# Same query using .query()
df.query("math_score >= 87 and science_score >= 87")
# Out:
#      first_name last_name  math_score  science_score
# 0      Danielle      Wood         100             95
# 17      Bridget   Johnson          92            100
# 25      Matthew    Foster          88             98
# 26  Christopher     Rocha          97            100
# 46        Craig   Ferrell          94             96

# %% [markdown]
# ### 🧪 Try It Yourself
#
# - Sort the dataset by first name alphabetically
# - Find students with the same math and science score
# - Use `.query()` to find students who scored over 95 in *either* subject

# %%
# 1. Sort by first name
sorted_df = df.sort_values(by="first_name")

# 2. Find students with same math and science score
same_score = df[df["math_score"] == df["science_score"]]

# 3. Query students > 95 in EITHER subject
high_achievers = df.query("math_score > 95 or science_score > 95")

print("Students with matching scores:\n", same_score)
print("\nHigh Achievers:\n", high_achievers.head())
# Out:
# Students with matching scores:
#  Empty DataFrame
# Columns: [first_name, last_name, math_score, science_score]
# Index: []
#
# High Achievers:
#     first_name last_name  math_score  science_score
# 0    Danielle      Wood         100             95
# 2      Joshua     Adams          61            100
# 3     Jeffrey    Zuniga          77             99
# 5       Erica     Lynch          74             96
# 10    Jeffery      Mayo          97             78

# %% [markdown]
# ### 🧠 Mini-Challenge
#
# > Load `"data/survey.csv"` and:
# - Sort by the most recent signup date
# - Filter out anyone who didn't complete the survey (nulls or "N/A")
# - Use `.query()` to select rows with a specific condition of your choice

# %%
import pandas as pd

survey_data = pd.read_csv("survey.csv")

survey_sorted = survey_data.sort_values(by="date", ascending=False)

complete_surveys = survey_sorted[survey_sorted["rating"].notnull()]

bad_reviews = survey_sorted.query("rating < 3")

print("\nBad Reviews:\n", bad_reviews)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 import pandas as pd
# ----> 3 survey_data = pd.read_csv("survey.csv")
#       5 survey_sorted = survey_data.sort_values(by="date", ascending=False)
#       7 complete_surveys = survey_sorted[survey_sorted["rating"].notnull()]
#
# File c:\Users\kingj\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\kingj\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\kingj\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\kingj\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\kingj\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'survey.csv'

# %% [markdown]
# ### 📝 Summary
#
# | Task              | Code Example                                 |
# |-------------------|-----------------------------------------------|
# | Sort by column     | `df.sort_values(by="col")`                  |
# | Filter condition   | `df[df["col"] > value]`                     |
# | Combine filters    | `df[(cond1) & (cond2)]`                     |
# | Query method       | `df.query("col > value and col2 < value")`  |
