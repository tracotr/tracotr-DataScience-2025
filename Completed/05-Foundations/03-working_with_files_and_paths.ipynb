# %% [markdown]
# # 📂 03 - Working with Files and Paths
#
# Data science means working with files all the time: datasets, config files, logs.
# This notebook introduces:
# - Checking your current path in Jupyter
# - Navigating directories
# - Reading and writing text files
# - Using `with` for safe file handling
# - Basics of JSON and CSV I/O

# %% [markdown]
# ## 1. Where Am I?

# %%
# %pwd  # Print current working directory
# Out:
# 'c:\\Users\\kingj\\Desktop\\DataScience\\tracotr-DataScience-2025\\Completed'

# %%
# %ls  # List files in the current directory
# Out:
#  Volume in drive C is Windows SSD
#  Volume Serial Number is FA10-B13F
#
#  Directory of c:\Users\kingj\Desktop\DataScience\tracotr-DataScience-2025\Completed
#
#
#  Directory of c:\Users\kingj\Desktop\DataScience\tracotr-DataScience-2025\Completed
#
#
#  Directory of c:\Users\kingj\Desktop\DataScience\tracotr-DataScience-2025\Completed
#
#
#  Directory of c:\Users\kingj\Desktop\DataScience\tracotr-DataScience-2025\Completed
#
#
#  Directory of c:\Users\kingj\Desktop\DataScience\tracotr-DataScience-2025\Completed
#
#
#  Directory of c:\Users\kingj\Desktop\DataScience\tracotr-DataScience-2025\Completed
#
#
#  Directory of c:\Users\kingj\Desktop\DataScience\tracotr-DataScience-2025\Completed
# File Not Found

# %%
# %cd ..  # Change to parent directory
# %pwd
# Out:
# [WinError 2] The system cannot find the file specified: '.. # Change to parent directory'
# c:\Users\kingj\Desktop\DataScience\tracotr-DataScience-2025\Completed
# 'c:\\Users\\kingj\\Desktop\\DataScience\\tracotr-DataScience-2025\\Completed'

# %% [markdown]
# ✅ **Your Turn**: Navigate into a subfolder of your repo (e.g., `Foundations/`) and list its contents.

# %%
# %cd ..
# %ls
# Out:
# c:\Users\kingj\Desktop\DataScience\tracotr-DataScience-2025
#  Volume in drive C is Windows SSD
#  Volume Serial Number is FA10-B13F
#
#  Directory of c:\Users\kingj\Desktop\DataScience\tracotr-DataScience-2025
#
# 10/11/2025  10:03 PM    <DIR>          .
# 09/06/2025  04:29 PM    <DIR>          ..
# 10/01/2025  11:06 PM    <DIR>          Assignments
# 10/11/2025  10:19 PM    <DIR>          Completed
# 09/06/2025  04:29 PM                26 README.md
#                1 File(s)             26 bytes
#                4 Dir(s)  117,438,615,552 bytes free

# %% [markdown]
# ## 2. Writing and Reading Text Files

# %%
# Writing to a text file
with open("example.txt", "w") as f:
    f.write("Hello, Jupyter!\n")
    f.write("This is a text file.\n")

# %%
# Reading from a text file
with open("example.txt", "r") as f:
    contents = f.read()
contents
# Out:
# 'Hello, Jupyter!\nThis is a text file.\n'

# %% [markdown]
# ✅ **Your Turn**: Write your name into a file called `me.txt`, then read it back and print the result.

# %%
with open("me.txt", "w") as f:
    f.write("Jaxon King\n")

with open("me.txt", "r") as f:
    contents = f.read()
print(contents)
# Out:
# Jaxon King

# %% [markdown]
# ## 3. JSON Files

# %%
import json

data = {"name": "Graylian", "type": "mascot", "skills": ["howl", "parrot talk"]}

# Write JSON
with open("data.json", "w") as f:
    json.dump(data, f)

# Read JSON
with open("data.json", "r") as f:
    loaded = json.load(f)
loaded
# Out:
# {'name': 'Graylian', 'type': 'mascot', 'skills': ['howl', 'parrot talk']}

# %% [markdown]
# ✅ **Your Turn**: Create a dictionary with your name and 2-3 favorite courses. Save it to `courses.json`, then read it back.

# %%
import json
data = {"favorite courses": ["Linear Algebra", "Data Structures", "Philosophy"]}

with open("courses.json", "w") as f:
    json.dump(data, f)

with open("courses.json", "r") as f:
    loaded = json.load(f)

print(loaded)
# Out:
# {'favorite courses': ['Linear Algebra', 'Data Structures', 'Philosophy']}

# %% [markdown]
# ## 4. CSV Files

# %%
import csv

# Writing CSV
rows = [["Name", "Score"], ["Alice", 90], ["Bob", 85]]
with open("scores.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# Reading CSV
with open("scores.csv", "r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Score']
# ['Alice', '90']
# ['Bob', '85']

# %% [markdown]
# ✅ **Your Turn**: Create a CSV with 3 rows of your own data (e.g., pets, grades, or hobbies). Read it back and display the rows.

# %%
import csv

rows = [["Name", "Pets", "Hobby"], ["Jaxon", "None", "Lounging around"], ["Jimmy", "Blowfish", "Fishing"], ["Randy", "Persian Cat", "Racing"]]
# Writing to the csv file
with open('rows.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(rows)

print("Contents")
with open('rows.csv', 'r') as file:
    reader = csv.reader(file)
    for line in reader:
        print(line)
# Out:
# Contents
# ['Name', 'Pets', 'Hobby']
# ['Jaxon', 'None', 'Lounging around']
# ['Jimmy', 'Blowfish', 'Fishing']
# ['Randy', 'Persian Cat', 'Racing']

# %% [markdown]
# ---
# ### Summary
# - `%pwd`, `%ls`, `%cd` show you where you are in the filesystem.
# - Use `with open(...)` to safely read/write files.
# - JSON is for structured data (key/value).
# - CSV is for tabular data (rows/columns).
# - Managing files is step 1 in any real data science project.
